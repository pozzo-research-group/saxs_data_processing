# %% [markdown]
# ## Data aggregation
#
# Goal: create 1 dataset with relevant synthesis parameters and measurement outcomes for everything I've made
#
# Columns in output: UUID, volume fractions of everything, fit results processed with Null if version wasn't best

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import json

# %% [markdown]
# ## Load synthesis files

# %%
synthesis_files = ['/home/bgpelkie/Code/silica-np-synthesis/2024_10_14_highlights_replicates/2024_10_14_highlights_replicates_sampletable.csv', '/home/bgpelkie/Code/silica-np-synthesis/2024_10_07_randomSampleV3/Sample_table_2024_10_07_randomsampleV3.csv', '/home/bgpelkie/Code/silica-np-synthesis/2024_10_04_RandomBaseline_v2/Sample_table_2024_10_04_randomsampleV2.csv', '/home/bgpelkie/Code/silica-np-synthesis/2024_10_17_RandomBaselineV4/Sample_table_2024_10_17_RandomBaselineV4.csv']

# %%
synth_tables = []

for fp in synthesis_files:
    data= pd.read_csv(fp)
    synth_tables.append(data)

synth_table = pd.concat(synth_tables, axis = 0)

# %%
synth_table
# Out:
#     Unnamed: 0.1  Unnamed: 0                                  uuid  \
# 0            0.0         0.0  4fd21940-a331-4524-b730-cf76de1b4d8d
# 1            2.0         2.0  8933d4b1-8929-4b58-a491-a0c55df30fed
# 2            5.0         5.0  130093e4-2947-4d37-b73a-ed4c23442ab8
# 3            6.0         6.0  a3f7d49b-cc77-4468-aae0-ad451027ddc0
# 4            8.0         8.0  f69628da-ff56-4f3a-ba2e-816036b87557
# ..           ...         ...                                   ...
# 35           NaN        35.0  49908a7b-72dd-4050-aab5-05b2807f82f8
# 36           NaN        36.0  5dca1867-c2bf-4e16-893b-57ec828b4951
# 37           NaN        37.0  21ae2275-1852-4a8d-b2dc-6ec0b850491a
# 38           NaN        38.0  d112b2bd-0447-459e-b875-15fb7e52b51f
# 39           NaN        39.0  69bb4bea-49e0-4142-b3d6-7c4fbe1993f7
#
#     teos_volume  ammonia_volume  water_volume  ethanol_volume  \
# 0     50.000000      124.000000    165.000000     1361.000000
# 1     83.000000       58.000000    175.000000     1384.000000
# 2     20.000000       64.000000     49.000000     1567.000000
# 3    181.000000        9.000000    228.000000     1283.000000
# 4    100.000000       52.000000     15.000000     1534.000000
# ..          ...             ...           ...             ...
# 35    60.410553       94.258186     21.613657     1523.717603
# 36    94.733145      141.702552     95.777438     1367.786865
# 37    83.552676      104.173866     91.429381     1420.844077
# 38   113.713415       66.366096    222.160905     1297.759584
# 39    90.518169       94.714111    192.961617     1321.806103
#
#     dilution_volume_fraction  silica_mass_conc  silica_mass_fraction well  \
# 0                   0.362682          7.951422              0.009674   A1
# 1                   0.218193         13.216927              0.016085   A2
# 2                   0.903794          3.190814              0.003982   A3
# 3                   0.100743         28.625618              0.034357   A4
# 4                   0.182971         15.761151              0.019630   A5
# ..                       ...               ...                   ...  ...
# 35                  0.452263          9.564710              0.011908   E8
# 36                  0.288404         14.998954              0.018328   F1
# 37                  0.326996         13.228767              0.016243   F2
# 38                  0.240266         18.004071              0.021676   F3
# 39                  0.301834         14.331603              0.017332   F4
#
#     ethanol_dilute_vol  sample_dilute_vol
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ..                 ...                ...
# 35               931.0              769.0
# 36              1210.0              490.0
# 37              1144.0              556.0
# 38              1292.0              408.0
# 39              1187.0              513.0
#
# [140 rows x 13 columns]

# %%
synth_table = synth_table.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis = 1)
synth_table = synth_table.drop(['well'], axis = 1)

# %%
synth_table = synth_table.set_index('uuid')

# %% [markdown]
# ## Load fitting file

# %%
with open('sasview_fit_batch_2024_10_24.json', 'rt') as f:
    fit_results = json.load(f)

# %% [markdown]
# ## Get volume fractions

# %%
def target_vol(row):
    target_vol = row['teos_volume'] + row['ammonia_volume'] + row['water_volume'] + row['ethanol_volume']
    return target_vol

# %%
synth_table['target_volume'] = synth_table.apply(target_vol, axis=1)

# %%
synth_table['teos_vol_frac'] = synth_table['teos_volume']/synth_table['target_volume']
synth_table['ammonia_vol_frac'] = synth_table['ammonia_volume']/synth_table['target_volume']
synth_table['water_vol_frac'] = synth_table['water_volume']/synth_table['target_volume']
synth_table['ethanol_vol_frac'] = synth_table['ethanol_volume']/synth_table['target_volume']

# %%
synth_table
# Out:
#                                       teos_volume  ammonia_volume  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d    50.000000      124.000000
# 8933d4b1-8929-4b58-a491-a0c55df30fed    83.000000       58.000000
# 130093e4-2947-4d37-b73a-ed4c23442ab8    20.000000       64.000000
# a3f7d49b-cc77-4468-aae0-ad451027ddc0   181.000000        9.000000
# f69628da-ff56-4f3a-ba2e-816036b87557   100.000000       52.000000
# ...                                           ...             ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8    60.410553       94.258186
# 5dca1867-c2bf-4e16-893b-57ec828b4951    94.733145      141.702552
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a    83.552676      104.173866
# d112b2bd-0447-459e-b875-15fb7e52b51f   113.713415       66.366096
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7    90.518169       94.714111
#
#                                       water_volume  ethanol_volume  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d    165.000000     1361.000000
# 8933d4b1-8929-4b58-a491-a0c55df30fed    175.000000     1384.000000
# 130093e4-2947-4d37-b73a-ed4c23442ab8     49.000000     1567.000000
# a3f7d49b-cc77-4468-aae0-ad451027ddc0    228.000000     1283.000000
# f69628da-ff56-4f3a-ba2e-816036b87557     15.000000     1534.000000
# ...                                            ...             ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8     21.613657     1523.717603
# 5dca1867-c2bf-4e16-893b-57ec828b4951     95.777438     1367.786865
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a     91.429381     1420.844077
# d112b2bd-0447-459e-b875-15fb7e52b51f    222.160905     1297.759584
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7    192.961617     1321.806103
#
#                                       dilution_volume_fraction  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d                  0.362682
# 8933d4b1-8929-4b58-a491-a0c55df30fed                  0.218193
# 130093e4-2947-4d37-b73a-ed4c23442ab8                  0.903794
# a3f7d49b-cc77-4468-aae0-ad451027ddc0                  0.100743
# f69628da-ff56-4f3a-ba2e-816036b87557                  0.182971
# ...                                                        ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8                  0.452263
# 5dca1867-c2bf-4e16-893b-57ec828b4951                  0.288404
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a                  0.326996
# d112b2bd-0447-459e-b875-15fb7e52b51f                  0.240266
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7                  0.301834
#
#                                       silica_mass_conc  silica_mass_fraction  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d          7.951422              0.009674
# 8933d4b1-8929-4b58-a491-a0c55df30fed         13.216927              0.016085
# 130093e4-2947-4d37-b73a-ed4c23442ab8          3.190814              0.003982
# a3f7d49b-cc77-4468-aae0-ad451027ddc0         28.625618              0.034357
# f69628da-ff56-4f3a-ba2e-816036b87557         15.761151              0.019630
# ...                                                ...                   ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8          9.564710              0.011908
# 5dca1867-c2bf-4e16-893b-57ec828b4951         14.998954              0.018328
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a         13.228767              0.016243
# d112b2bd-0447-459e-b875-15fb7e52b51f         18.004071              0.021676
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7         14.331603              0.017332
#
#                                       ethanol_dilute_vol  sample_dilute_vol  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d                 NaN                NaN
# 8933d4b1-8929-4b58-a491-a0c55df30fed                 NaN                NaN
# 130093e4-2947-4d37-b73a-ed4c23442ab8                 NaN                NaN
# a3f7d49b-cc77-4468-aae0-ad451027ddc0                 NaN                NaN
# f69628da-ff56-4f3a-ba2e-816036b87557                 NaN                NaN
# ...                                                  ...                ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8               931.0              769.0
# 5dca1867-c2bf-4e16-893b-57ec828b4951              1210.0              490.0
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a              1144.0              556.0
# d112b2bd-0447-459e-b875-15fb7e52b51f              1292.0              408.0
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7              1187.0              513.0
#
#                                       target_volume  teos_vol_frac  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d         1700.0       0.029412
# 8933d4b1-8929-4b58-a491-a0c55df30fed         1700.0       0.048824
# 130093e4-2947-4d37-b73a-ed4c23442ab8         1700.0       0.011765
# a3f7d49b-cc77-4468-aae0-ad451027ddc0         1701.0       0.106408
# f69628da-ff56-4f3a-ba2e-816036b87557         1701.0       0.058789
# ...                                             ...            ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8         1700.0       0.035536
# 5dca1867-c2bf-4e16-893b-57ec828b4951         1700.0       0.055725
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a         1700.0       0.049149
# d112b2bd-0447-459e-b875-15fb7e52b51f         1700.0       0.066890
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7         1700.0       0.053246
#
#                                       ammonia_vol_frac  water_vol_frac  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d          0.072941        0.097059
# 8933d4b1-8929-4b58-a491-a0c55df30fed          0.034118        0.102941
# 130093e4-2947-4d37-b73a-ed4c23442ab8          0.037647        0.028824
# a3f7d49b-cc77-4468-aae0-ad451027ddc0          0.005291        0.134039
# f69628da-ff56-4f3a-ba2e-816036b87557          0.030570        0.008818
# ...                                                ...             ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8          0.055446        0.012714
# 5dca1867-c2bf-4e16-893b-57ec828b4951          0.083354        0.056340
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a          0.061279        0.053782
# d112b2bd-0447-459e-b875-15fb7e52b51f          0.039039        0.130683
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7          0.055714        0.113507
#
#                                       ethanol_vol_frac
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d          0.800588
# 8933d4b1-8929-4b58-a491-a0c55df30fed          0.814118
# 130093e4-2947-4d37-b73a-ed4c23442ab8          0.921765
# a3f7d49b-cc77-4468-aae0-ad451027ddc0          0.754262
# f69628da-ff56-4f3a-ba2e-816036b87557          0.901822
# ...                                                ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8          0.896304
# 5dca1867-c2bf-4e16-893b-57ec828b4951          0.804581
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a          0.835791
# d112b2bd-0447-459e-b875-15fb7e52b51f          0.763388
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7          0.777533
#
# [140 rows x 14 columns]

# %%
fail_count = 0

fits = []
for i, row in synth_table.iterrows():
    uuid_val = row.name

    try:
        fit = fit_results[uuid_val]
        fit_status = 'Success'
    except:
        print('failed fit for, uuid_val')
        fail_count +=1
        fit_status = 'Failed'
        fit = {'best_fit': None,
                 'd_nm': None,
                 'pdi': None,
                 'pl_power': None,
                 'd_gprg': None}
    fit['fit_status'] = fit_status
    fit['uuid'] = uuid_val
    fits.append(fit)
# Out:
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val
# failed fit for, uuid_val

# %%
row.name
# Out:
# '69bb4bea-49e0-4142-b3d6-7c4fbe1993f7'

# %%
fit_df = pd.DataFrame(fits)
fit_df = fit_df.set_index('uuid')

# %%
synth_fit_table = pd.concat([synth_table, fit_df], axis = 1)

# %%
synth_fit_table
# Out:
#                                       teos_volume  ammonia_volume  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d    50.000000      124.000000
# 8933d4b1-8929-4b58-a491-a0c55df30fed    83.000000       58.000000
# 130093e4-2947-4d37-b73a-ed4c23442ab8    20.000000       64.000000
# a3f7d49b-cc77-4468-aae0-ad451027ddc0   181.000000        9.000000
# f69628da-ff56-4f3a-ba2e-816036b87557   100.000000       52.000000
# ...                                           ...             ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8    60.410553       94.258186
# 5dca1867-c2bf-4e16-893b-57ec828b4951    94.733145      141.702552
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a    83.552676      104.173866
# d112b2bd-0447-459e-b875-15fb7e52b51f   113.713415       66.366096
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7    90.518169       94.714111
#
#                                       water_volume  ethanol_volume  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d    165.000000     1361.000000
# 8933d4b1-8929-4b58-a491-a0c55df30fed    175.000000     1384.000000
# 130093e4-2947-4d37-b73a-ed4c23442ab8     49.000000     1567.000000
# a3f7d49b-cc77-4468-aae0-ad451027ddc0    228.000000     1283.000000
# f69628da-ff56-4f3a-ba2e-816036b87557     15.000000     1534.000000
# ...                                            ...             ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8     21.613657     1523.717603
# 5dca1867-c2bf-4e16-893b-57ec828b4951     95.777438     1367.786865
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a     91.429381     1420.844077
# d112b2bd-0447-459e-b875-15fb7e52b51f    222.160905     1297.759584
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7    192.961617     1321.806103
#
#                                       dilution_volume_fraction  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d                  0.362682
# 8933d4b1-8929-4b58-a491-a0c55df30fed                  0.218193
# 130093e4-2947-4d37-b73a-ed4c23442ab8                  0.903794
# a3f7d49b-cc77-4468-aae0-ad451027ddc0                  0.100743
# f69628da-ff56-4f3a-ba2e-816036b87557                  0.182971
# ...                                                        ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8                  0.452263
# 5dca1867-c2bf-4e16-893b-57ec828b4951                  0.288404
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a                  0.326996
# d112b2bd-0447-459e-b875-15fb7e52b51f                  0.240266
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7                  0.301834
#
#                                       silica_mass_conc  silica_mass_fraction  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d          7.951422              0.009674
# 8933d4b1-8929-4b58-a491-a0c55df30fed         13.216927              0.016085
# 130093e4-2947-4d37-b73a-ed4c23442ab8          3.190814              0.003982
# a3f7d49b-cc77-4468-aae0-ad451027ddc0         28.625618              0.034357
# f69628da-ff56-4f3a-ba2e-816036b87557         15.761151              0.019630
# ...                                                ...                   ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8          9.564710              0.011908
# 5dca1867-c2bf-4e16-893b-57ec828b4951         14.998954              0.018328
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a         13.228767              0.016243
# d112b2bd-0447-459e-b875-15fb7e52b51f         18.004071              0.021676
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7         14.331603              0.017332
#
#                                       ethanol_dilute_vol  sample_dilute_vol  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d                 NaN                NaN
# 8933d4b1-8929-4b58-a491-a0c55df30fed                 NaN                NaN
# 130093e4-2947-4d37-b73a-ed4c23442ab8                 NaN                NaN
# a3f7d49b-cc77-4468-aae0-ad451027ddc0                 NaN                NaN
# f69628da-ff56-4f3a-ba2e-816036b87557                 NaN                NaN
# ...                                                  ...                ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8               931.0              769.0
# 5dca1867-c2bf-4e16-893b-57ec828b4951              1210.0              490.0
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a              1144.0              556.0
# d112b2bd-0447-459e-b875-15fb7e52b51f              1292.0              408.0
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7              1187.0              513.0
#
#                                       target_volume  teos_vol_frac  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d         1700.0       0.029412
# 8933d4b1-8929-4b58-a491-a0c55df30fed         1700.0       0.048824
# 130093e4-2947-4d37-b73a-ed4c23442ab8         1700.0       0.011765
# a3f7d49b-cc77-4468-aae0-ad451027ddc0         1701.0       0.106408
# f69628da-ff56-4f3a-ba2e-816036b87557         1701.0       0.058789
# ...                                             ...            ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8         1700.0       0.035536
# 5dca1867-c2bf-4e16-893b-57ec828b4951         1700.0       0.055725
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a         1700.0       0.049149
# d112b2bd-0447-459e-b875-15fb7e52b51f         1700.0       0.066890
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7         1700.0       0.053246
#
#                                       ammonia_vol_frac  water_vol_frac  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d          0.072941        0.097059
# 8933d4b1-8929-4b58-a491-a0c55df30fed          0.034118        0.102941
# 130093e4-2947-4d37-b73a-ed4c23442ab8          0.037647        0.028824
# a3f7d49b-cc77-4468-aae0-ad451027ddc0          0.005291        0.134039
# f69628da-ff56-4f3a-ba2e-816036b87557          0.030570        0.008818
# ...                                                ...             ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8          0.055446        0.012714
# 5dca1867-c2bf-4e16-893b-57ec828b4951          0.083354        0.056340
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a          0.061279        0.053782
# d112b2bd-0447-459e-b875-15fb7e52b51f          0.039039        0.130683
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7          0.055714        0.113507
#
#                                       ethanol_vol_frac       best_fit  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d          0.800588           None
# 8933d4b1-8929-4b58-a491-a0c55df30fed          0.814118           None
# 130093e4-2947-4d37-b73a-ed4c23442ab8          0.921765         sphere
# a3f7d49b-cc77-4468-aae0-ad451027ddc0          0.754262  guinier_porod
# f69628da-ff56-4f3a-ba2e-816036b87557          0.901822  guinier_porod
# ...                                                ...            ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8          0.896304           None
# 5dca1867-c2bf-4e16-893b-57ec828b4951          0.804581           None
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a          0.835791           None
# d112b2bd-0447-459e-b875-15fb7e52b51f          0.763388           None
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7          0.777533           None
#
#                                             d_nm       pdi  pl_power  \
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d         NaN       NaN       NaN
# 8933d4b1-8929-4b58-a491-a0c55df30fed         NaN       NaN       NaN
# 130093e4-2947-4d37-b73a-ed4c23442ab8  113.992098  0.172859       NaN
# a3f7d49b-cc77-4468-aae0-ad451027ddc0         NaN       NaN       NaN
# f69628da-ff56-4f3a-ba2e-816036b87557         NaN       NaN       NaN
# ...                                          ...       ...       ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8         NaN       NaN       NaN
# 5dca1867-c2bf-4e16-893b-57ec828b4951         NaN       NaN       NaN
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a         NaN       NaN       NaN
# d112b2bd-0447-459e-b875-15fb7e52b51f         NaN       NaN       NaN
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7         NaN       NaN       NaN
#
#                                          d_gprg fit_status
# uuid
# 4fd21940-a331-4524-b730-cf76de1b4d8d        NaN     Failed
# 8933d4b1-8929-4b58-a491-a0c55df30fed        NaN     Failed
# 130093e4-2947-4d37-b73a-ed4c23442ab8        NaN    Success
# a3f7d49b-cc77-4468-aae0-ad451027ddc0  99.778936    Success
# f69628da-ff56-4f3a-ba2e-816036b87557  99.778936    Success
# ...                                         ...        ...
# 49908a7b-72dd-4050-aab5-05b2807f82f8        NaN     Failed
# 5dca1867-c2bf-4e16-893b-57ec828b4951        NaN     Failed
# 21ae2275-1852-4a8d-b2dc-6ec0b850491a        NaN     Failed
# d112b2bd-0447-459e-b875-15fb7e52b51f        NaN     Failed
# 69bb4bea-49e0-4142-b3d6-7c4fbe1993f7        NaN     Failed
#
# [140 rows x 20 columns]

# %%
len(synth_fit_table[synth_fit_table['best_fit'] == 'sphere'])
# Out:
# 11
